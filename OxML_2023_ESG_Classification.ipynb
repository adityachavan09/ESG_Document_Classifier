# %% [markdown]
# <a href="https://colab.research.google.com/github/adityachavan09/ESG_Classifier/blob/main/OxML_2023_ESG_Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q transformers datasets PyPDF2 accelerate pycryptodome

# %% [markdown]
# # Imports

# %%
import os
import shutil

from PyPDF2 import PdfReader

import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import f1_score

import plotly.express as px

import torch
from torch.utils.data import DataLoader, Dataset
from transformers import AdamW, AutoTokenizer, AutoModelForSequenceClassification, DataCollatorWithPadding, TrainingArguments, Trainer

# %% [markdown]
# # Pre-Reqs and Helper Functions

# %%
DRIVE = True # If you are loading data from drive, keep this as true

DRIVE_BASE_PATH = '/content/drive/MyDrive/OxML Task 1'

if DRIVE:
  from google.colab import drive
  drive.mount('/content/drive', force_remount=True)

  if not os.path.exists("/content/oxml"):
    shutil.copytree(DRIVE_BASE_PATH, '/content/oxml')
# Out:
# Mounted at /content/drive

# %%
BASE_PATH = '/content/oxml'
REPORTS_PATH = os.path.join(BASE_PATH, 'data', 'reports')

def extract_text_from_pdf_with_path(pdf_path, page_number):
  try:
    page_index = page_number - 1
    reader = PdfReader(pdf_path)
    page = reader.pages[page_index]
    return page.extract_text()
  except Exception as e:
    print(f'Exception occurred for pdf = {pdf_path} and page = {page_number}')
    print(e)

# %%
mock_pdf_path = os.path.join(REPORTS_PATH, 'report_1827.pdf')
mock_page = 4
pdf_text = extract_text_from_pdf_with_path(mock_pdf_path, mock_page)
pdf_text
# Out:
# 'Financial Highlights 2018 (IFRS)\n2018 2017 Change\nOperating Highlights (€ in millions)\nNet sales 121,915 21,218 3%\nGross profit 111,363 10,703 6%\nOther operating expenses 1, 29,172 8,766 5%\nEBITDA 12,882 2,511 15%\nOperating profit 12,368 2,070 14%\nNet income from continuing operations 1, 31,709 1,430 20%\nNet income attributable to shareholders 3, 41,702 1,173 45%\nKey RatiosGross margin\n 151.8% 50.4% 1.4pp\nOther operating expenses in % of net sales 1, 241.9% 41.3% 0.5pp\nOperating margin 110.8% 9.8% 1.1pp\nEffective tax rate 1, 328.1% 29.3% (1.2pp)\nNet income attributable to shareholders in % of net  sal\nes 3, 47.8% 5.5% 2.2pp\nAverage operating working capital in % of net  sal\nes 119.0% 20.4% (1.4pp)\nEquity ratio 540.8% 43.0% (2.2pp)\nNet borrowings/EBITDA 1(0.3) (0.2) n.a.\nFinancial leverage 5(15.0%) (8.0%) (7.0pp)\nReturn on equity 4, 526.7% 18.2% 8.5pp\nBalance Sheet and Cash Flow Data (€ in millions)Total assets\n 515,612 14,019 11%\nInventories 3,445 3,692 (7%)\nReceivables and other  curr\nent assets 3,734 3,277 14%\nOperating working capital 3,563 4,033 (12%)\nNet cash 959 484 98%\nShareholders’ equity 56,377 6,032 6%\nCapital expenditure 1794 752 6%\nNet cash generated from operating activities 42,646 1,648 61%\nPer Share of Common Stock (€)Basic earnings\n 1, 38.46 7.05 20%\nDiluted earnings 1, 38.45 7.00 21%\nNet cash generated from operating activities 413.11 8.14 61%\nDividend 3.35 62.60 29%\nShare price at year-end 182.40 167.15 9%\nOther (at year-end)Number of employees\n 157,016 56,888 0%\nNumber of shares outstanding 199,171,345 203,861,234 (2%)\nAverage number of shares 201,759,012 202,391,673 0%\n1 Figures reflect continuing operations as a result of the divestiture of the Rockport, TaylorMade, Adams Golf, Ashworth and CCM Hockey businesses. \n2 Figures reflect the adjusted consolidated income statement structure introduced in 2018.3 2017 excluding negative one-time tax impact of € 76 million.4 Includes continuing and discontinued operations.5 2017 restated according to IAS 8, see Note 03.6 Subject to Annual General Meeting approval. FINANCIAL HIGHLIGHTS 2018 (IFRS)004\nADIDAS  ANNUAL REP ORT 2018'

# %% [markdown]
# # Data Loading

# %%
LABELS_PATH = os.path.join(BASE_PATH, 'data', 'labels.csv')

df = pd.read_csv(LABELS_PATH)
df.sample(20)
# Out:
#                        id          class
# 947    report_1132.pdf.27     governance
# 971     report_189.pdf.14  environmental
# 1462    report_422.pdf.15  environmental
# 377     report_711.pdf.69  environmental
# 57     report_1830.pdf.66          other
# 322     report_733.pdf.14         social
# 28     report_1825.pdf.38          other
# 1295   report_1132.pdf.23         social
# 1206  report_1241.pdf.133  environmental
# 1898   report_1828.pdf.79          other
# 1835  report_1827.pdf.141          other
# 573   report_1827.pdf.192          other
# 648   report_1825.pdf.347          other
# 645   report_1825.pdf.313          other
# 1390    report_888.pdf.59  environmental
# 272     report_311.pdf.29     governance
# 66    report_1826.pdf.258          other
# 834   report_1825.pdf.364          other
# 1888  report_1831.pdf.243          other
# 1000    report_711.pdf.54  environmental

# %%
df['report_name'] = [x.split('pdf.')[0] + 'pdf' for x in df['id']]
df['page_number'] = [x.split('pdf.')[1] for x in df['id']]
df['page_number'] = df['page_number'].astype(int)

df.sample(20)
# Out:
#                        id          class      report_name  page_number
# 666    report_1611.pdf.20         social  report_1611.pdf           20
# 1269  report_1825.pdf.222          other  report_1825.pdf          222
# 951    report_1832.pdf.41          other  report_1832.pdf           41
# 1295   report_1132.pdf.23         social  report_1132.pdf           23
# 238   report_1827.pdf.212          other  report_1827.pdf          212
# 680    report_1824.pdf.27          other  report_1824.pdf           27
# 354   report_1825.pdf.226          other  report_1825.pdf          226
# 93     report_711.pdf.175     governance   report_711.pdf          175
# 813    report_1828.pdf.97          other  report_1828.pdf           97
# 917   report_1831.pdf.116          other  report_1831.pdf          116
# 322     report_733.pdf.14         social   report_733.pdf           14
# 1004   report_1622.pdf.65         social  report_1622.pdf           65
# 969     report_1611.pdf.8  environmental  report_1611.pdf            8
# 1117     report_733.pdf.8  environmental   report_733.pdf            8
# 1241  report_1833.pdf.162          other  report_1833.pdf          162
# 682   report_1824.pdf.189          other  report_1824.pdf          189
# 1080   report_1155.pdf.17         social  report_1155.pdf           17
# 345    report_1825.pdf.99          other  report_1825.pdf           99
# 502     report_422.pdf.19  environmental   report_422.pdf           19
# 970    report_1831.pdf.25          other  report_1831.pdf           25

# %%
PROCESSED_DATA = '/content/oxml_data.csv'

if os.path.exists(PROCESSED_DATA):
  df = pd.read_csv(PROCESSED_DATA)
else:
  df['text'] = [extract_text_from_pdf_with_path(os.path.join(REPORTS_PATH, pdf_name), page_number) for pdf_name, page_number in zip(df['report_name'], df['page_number'])]

  df.to_csv('oxml_data.csv')

# %% [markdown]
# # EDA

# %%
df.sample(10)
# Out:
#       Unnamed: 0                   id          class      report_name  \
# 1666        1666    report_279.pdf.16  environmental   report_279.pdf
# 543          543  report_1825.pdf.355          other  report_1825.pdf
# 73            73  report_1827.pdf.215          other  report_1827.pdf
# 1933        1933   report_1706.pdf.17         social  report_1706.pdf
# 1013        1013  report_1827.pdf.235          other  report_1827.pdf
# 1701        1701   report_1181.pdf.38         social  report_1181.pdf
# 1237        1237   report_1253.pdf.57         social  report_1253.pdf
# 849          849   report_1430.pdf.24  environmental  report_1430.pdf
# 1865        1865  report_1826.pdf.223          other  report_1826.pdf
# 914          914    report_519.pdf.37         social   report_519.pdf
#
#       page_number                                               text
# 1666           16  Water\nWe recognize that water usage and sourc...
# 543           355      CONSOLIDATED FINANCIAL STATEMENTS \n5.6 NO...
# 73            215  Tax expenses\nTax expenses are split as follow...
# 1933           17  CROWN CASTLE  |  2019 CORPORATE SUSTAINABILITY...
# 1013          235  (systems) as they have considered necessary to...
# 1701           38   \n2021 Sustainability Report   38Introduction...
# 1237           57  Pfizer 2021 ESG Report57\n PerformanceThe Pati...
# 849            24  Introduction  Our Communities  Our People  Our...
# 1865          223  NOTES TO THE BALANCE SHEET / / NOTES TO THE CO...
# 914            37  2021 ESG Impact Report \n \n \n  \n \n \n \n \...

# %%
fig = px.pie(df, values=df['class'].value_counts().values, names=df['class'].value_counts().index)
fig.update_traces(hoverinfo='label+percent', textinfo='value')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="d5f0bd55-f5a0-4d74-b81a-bdb3dbd2aef3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d5f0bd55-f5a0-4d74-b81a-bdb3dbd2aef3")) {                    Plotly.newPlot(                        "d5f0bd55-f5a0-4d74-b81a-bdb3dbd2aef3",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"label=%{label}<br>value=%{value}<extra></extra>","labels":["other","social","environmental","governance"],"legendgroup":"","name":"","showlegend":true,"values":[913,466,345,232],"type":"pie","hoverinfo":"label+percent","textinfo":"value"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":" ...

# %% [markdown]
# # Train and Validate Transformer

# %%
le = LabelEncoder()
df['labels'] = le.fit_transform(df['class'])

# %%
df.sample(10)
# Out:
#       Unnamed: 0                   id          class      report_name  \
# 18            18  report_1833.pdf.187          other  report_1833.pdf
# 594          594  report_1824.pdf.283          other  report_1824.pdf
# 1718        1718   report_1683.pdf.21         social  report_1683.pdf
# 382          382   report_1829.pdf.79          other  report_1829.pdf
# 1890        1890   report_1622.pdf.45  environmental  report_1622.pdf
# 426          426   report_1155.pdf.23         social  report_1155.pdf
# 408          408   report_1611.pdf.19         social  report_1611.pdf
# 928          928   report_1132.pdf.16  environmental  report_1132.pdf
# 440          440   report_1237.pdf.39  environmental  report_1237.pdf
# 1613        1613  report_1827.pdf.246          other  report_1827.pdf
#
#       page_number                                               text  labels
# 18            187   Anglo American plc  Integrated Annual Report ...       2
# 594           283  ENVIRONMENTAL AND SOCIETAL REPORTING\n4\n Soci...       2
# 1718           21  GOVERNANCE CEO MESSAGE INNOVATION ASSOCIATES C...       3
# 382            79   \n \n \n C _ Group Management Report  \nAnnua...       2
# 1890           45  Topic-specific standards\nGRI 300: ENVIRONMENT...       0
# 426            23  Training\nTraining and development of our team...       3
# 408            19  Webuildstrongconnectionswithourcustomers.Welis...       3
# 928            16  For more than a decade, the Sunlight Advantage...       0
# 440            39  39ACCOUNTING METRIC CODE INFORMATION 2020\nTop...       0
# 1613          246  DECLARA TION \nOF SUPPOR\nT\nadidas AG declare...       2

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'id', 'class', 'report_name', 'page_number', 'text',
#        'labels'],
#       dtype='object')

# %%
transformer_name = 'nbroad/ESG-BERT'

tokenizer = AutoTokenizer.from_pretrained(transformer_name)

model = AutoModelForSequenceClassification.from_pretrained(transformer_name)

if torch.cuda.is_available():
  model = model.to('cuda')

# %%
class CustomDataset(Dataset):
    def __init__(self, dataframe, tokenizer):
        self.data = dataframe
        self.tokenizer = tokenizer

    def __len__(self):
        return len(self.data)

    def __getitem__(self, index):
        text = self.data.loc[index, 'text']
        label = self.data.loc[index, 'labels']
        encoding = self.tokenizer(text, truncation=True, padding='max_length', max_length=512)
        inputs = {
            'input_ids': torch.tensor(encoding['input_ids']),
            'attention_mask': torch.tensor(encoding['attention_mask']),
            'labels': torch.tensor(label)
        }
        return inputs

train_dataset = CustomDataset(df, tokenizer)

# %%
def data_collator(features):
    batch = {
        'input_ids': torch.stack([f['input_ids'] for f in features]),
        'attention_mask': torch.stack([f['attention_mask'] for f in features]),
        'labels': torch.stack([f['labels'] for f in features])
    }
    return batch

# %%
train_dataloader = DataLoader(train_dataset, batch_size=16, collate_fn=data_collator)

# %%
def compute_metrics(eval_pred):
    logits, labels = eval_pred.predictions, eval_pred.label_ids
    predictions = logits.argmax(axis=-1)
    f1 = f1_score(labels, predictions, average='weighted')
    return {"f1_score": f1}

# %%
training_args = TrainingArguments(
    output_dir='./results',
    num_train_epochs=5,
    per_device_train_batch_size=16,
    warmup_steps=500,
    weight_decay=0.01,
    logging_dir='./logs',
    logging_steps=50,
)

# Define the trainer
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    data_collator=data_collator,
    compute_metrics=compute_metrics
)

# %%
trainer.train()
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/optimization.py:411: FutureWarning:
#
# This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#     <div>
#
#       <progress value='615' max='615' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [615/615 16:23, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>50</td>
#       <td>3.935000</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>1.281500</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>0.586600</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>0.411300</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>0.425700</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>0.263300</td>
#     </tr>
#     <tr>
#       <td>350</td>
#       <td>0.247400</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>0.170300</td>
#     </tr>
#     <tr>
#       <td>450</td>
#       <td>0.190200</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>0.178200</td>
#     </tr>
#     <tr>
#       <td>550</td>
#       <td>0.145300</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>0.082400</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=615, training_loss=0.6458052200999687, metrics={'train_runtime': 985.2831, 'train_samples_per_second': 9.926, 'train_steps_per_second': 0.624, 'total_flos': 2573780616437760.0, 'train_loss': 0.6458052200999687, 'epoch': 5.0})

# %%
trainer.evaluate(train_dataset)
# Out:
#     <div>
#
#       <progress value='245' max='245' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [245/245 01:08]
#     </div>
# {'eval_loss': 0.04682925343513489,
#  'eval_f1_score': 0.9902979018008535,
#  'eval_runtime': 68.7357,
#  'eval_samples_per_second': 28.457,
#  'eval_steps_per_second': 3.564,
#  'epoch': 5.0}

# %% [markdown]
# # Submission

# %%
SUBMISSION_SAMPLE_PATH = os.path.join(BASE_PATH, 'sample_submission.csv')

submission = pd.read_csv(SUBMISSION_SAMPLE_PATH)

submission.sample(10)
# Out:
#                       id          class
# 55    report_1352.pdf.63  environmental
# 63    report_1352.pdf.84  environmental
# 33    report_1179.pdf.28  environmental
# 461  report_1012.pdf.116  environmental
# 72    report_1352.pdf.50  environmental
# 332    report_1179.pdf.8  environmental
# 228   report_1145.pdf.56  environmental
# 9      report_576.pdf.11  environmental
# 172   report_1179.pdf.29  environmental
# 229    report_576.pdf.15  environmental

# %%
submission['report_name'] = [x.split('pdf.')[0] + 'pdf' for x in submission['id']]
submission['page_number'] = [x.split('pdf.')[1] for x in submission['id']]
submission['page_number'] = submission['page_number'].astype(int)
submission['text'] = [extract_text_from_pdf_with_path(os.path.join(REPORTS_PATH, pdf_name), page_number) for pdf_name, page_number in zip(submission['report_name'], submission['page_number'])]
submission['labels'] = le.transform(submission['class'])

# %%
submission.sample(10)
# Out:
#                      id          class      report_name  page_number  \
# 323  report_1179.pdf.13  environmental  report_1179.pdf           13
# 194  report_1260.pdf.14  environmental  report_1260.pdf           14
# 30   report_1145.pdf.29  environmental  report_1145.pdf           29
# 295  report_1145.pdf.34  environmental  report_1145.pdf           34
# 294  report_1179.pdf.14  environmental  report_1179.pdf           14
# 63   report_1352.pdf.84  environmental  report_1352.pdf           84
# 215  report_1145.pdf.59  environmental  report_1145.pdf           59
# 168   report_293.pdf.92  environmental   report_293.pdf           92
# 127   report_293.pdf.55  environmental   report_293.pdf           55
# 243  report_1352.pdf.89  environmental  report_1352.pdf           89
#
#                                                   text  labels
# 323  FY21 ESG Data Disclosures\n2022 Unaudited 8whi...       0
# 194  CORPORATE GOVERNANCE\nHoneywell’s Board of Dir...       0
# 30   29\nEFFICIENCY IN OPERATIONS\nOur commitment t...       0
# 295  34\nGlobal program examples:\n• Lighting:  LED...       0
# 294  FY21 ESG Data Disclosures\n2022 Unaudited 9Eff...       0
# 63   LG H&H has an advanced governance structure ce...       0
# 215  59\n• Made it a top priority to drive inclusio...       0
# 168  Ferrexpo plc Responsible Business Report 2021 ...       0
# 127  SUPPORTING UKRAINE WORKFORCE ETHICAL BUSINESS ...       0
# 243  Integrated Risk Management System\nLG H&H oper...       0

# %%
test_dataset = CustomDataset(submission, tokenizer)
predictions = trainer.predict(test_dataset)

# %%
output_labels = predictions.predictions.argmax(axis=1)
class_labels = le.inverse_transform(output_labels)
submission['class'] = class_labels

# %%
submission.sample(10)
# Out:
#                       id          class      report_name  page_number  \
# 15   report_1352.pdf.117  environmental  report_1352.pdf          117
# 208   report_1352.pdf.54         social  report_1352.pdf           54
# 396   report_1179.pdf.41     governance  report_1179.pdf           41
# 339   report_1012.pdf.91         social  report_1012.pdf           91
# 101   report_1352.pdf.94     governance  report_1352.pdf           94
# 78    report_1179.pdf.19  environmental  report_1179.pdf           19
# 76    report_1260.pdf.19     governance  report_1260.pdf           19
# 67    report_1260.pdf.74         social  report_1260.pdf           74
# 425    report_576.pdf.32     governance   report_576.pdf           32
# 405   report_1352.pdf.86     governance  report_1352.pdf           86
#
#                                                   text  labels
# 15   Waste\nNOx 6)\n Total amount \nIntensityTotal ...       0
# 208  Activating employee communication\nOperating c...       0
# 396  FY21 ESG Data Disclosures\n2022 Unaudited 36Co...       0
# 339  PSEG\n2021 Sustainability and Climate Report89...       0
# 101  LG H&H is improving its rules and systems to e...       0
# 78   FY21 ESG Data Disclosures\n2022 Unaudited 14EN...       0
# 76   The framework is aligned to industry standards...       0
# 67   An essential element of Honeywell’s Corporate ...       0
# 425  2021 MAHA ENERGY SUSTAINABILITY REPORT\n59 60R...       0
# 405  Subcommittee\nAudit committee\nLG H&H operates...       0

# %%
submission[['id', 'class']].to_csv('submission.csv', index=False)
